# %% [markdown]
# ### Notebook for segmentation and clustering

# %%
import pandas as pd

# %% [markdown]
# ##- Reading the HTML table from the Wikipedia website to a pandas dataframe

# %%
url_wiki = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
column_names = ['PostalCode', 'Borough', 'Neighborhood'] 

# Initiating the dataframe
postal_code_df = pd.DataFrame(columns=column_names)

# Reading the HTML table from wikipedia website
postal_data = pd.read_html(url_wiki)

# %% [markdown]
# ### Create Data Frames

# %%
# Ignoring the rows with "Not assigned" values
postal_data[0]=postal_data[0][~postal_data[0]['Borough'].isin(['Not assigned'])]
postal_code_df = postal_data[0]

#Grouping the dataframe according to the instructions
postal_code_df = postal_code_df.groupby(['Postcode', 'Borough'], sort=False).agg( ','.join)
postal_code_df = postal_code_df.groupby(['Postcode','Borough'])['Neighbourhood'].apply(list)
postal_code_df = postal_code_df.sample(frac=1).reset_index()
postal_code_df['Neighbourhood']= postal_code_df['Neighbourhood'].str.join(', ')
postal_code_df
# Out:
#     Postcode           Borough  \
# 0        M1S       Scarborough
# 1        M9L        North York
# 2        M5P   Central Toronto
# 3        M1J       Scarborough
# 4        M4K      East Toronto
# 5        M2N        North York
# 6        M1R       Scarborough
# 7        M3K        North York
# 8        M4M      East Toronto
# 9        M6G  Downtown Toronto
# 10       M5G  Downtown Toronto
# 11       M7A  Downtown Toronto
# 12       M9N              York
# 13       M6P      West Toronto
# 14       M6B        North York
# 15       M5C  Downtown Toronto
# 16       M1H       Scarborough
# 17       M6J      West Toronto
# 18       M4S   Central Toronto
# 19       M5S  Downtown Toronto
# 20       M5N   Central Toronto
# 21       M5K  Downtown Toronto
# 22       M4C         East York
# 23       M7Y      East Toronto
# 24       M3C        North York
# 25       M4Y  Downtown Toronto
# 26       M4E      East Toronto
# 27       M2L        North York
# 28       M5T  Downtown Toronto
# 29       M4G         East York
# ..       ...               ...
# 73       M4B         East York
# 74       M9V         Etobicoke
# 75       M9A         Etobicoke
# 76       M1K       Scarborough
# 77       M3A        North York
# 78       M6R      West Toronto
# 79       M8W         Etobicoke
# 80       M6M              York
# 81       M4H         East York
# 82       M4A        North York
# 83       M1G       Scarborough
# 84       M8X         Etobicoke
# 85       M5R   Central Toronto
# 86       M2R        North York
# 87       M8Y         Etobicoke
# 88       M1C       Scarborough
# 89       M7R       Mississauga
# 90       M6N              York
# 91       M4W  Downtown Toronto
# 92       M6C              York
# 93       M5B  Downtown Toronto
# 94       M4L      East Toronto
# 95       M4N   Central Toronto
# 96       M9P         Etobicoke
# 97       M6L        North York
# 98       M4P   Central Toronto
# 99       M1W       Scarborough
# 100      M5A  Downtown Toronto
# 101      M1M       Scarborough
# 102      M5M        North York
#
#                                          Neighbourhood
# 0                                            Agincourt
# 1                                        Humber Summit
# 2                   Forest Hill North,Forest Hill West
# 3                                  Scarborough Village
# 4                          The Danforth West,Riverdale
# 5                                     Willowdale South
# 6                                     Maryvale,Wexford
# 7                           CFB Toronto,Downsview East
# 8                                      Studio District
# 9                                             Christie
# 10                                  Central Bay Street
# 11                                        Queen's Park
# 12                                              Weston
# 13                        High Park,The Junction South
# 14                                           Glencairn
# 15                                      St. James Town
# 16                                           Cedarbrae
# 17                             Little Portugal,Trinity
# 18                                          Davisville
# 19                       Harbord,University of Toronto
# 20                                            Roselawn
# 21             Design Exchange,Toronto Dominion Centre
# 22                                    Woodbine Heights
# 23   Business Reply Mail Processing Centre 969 Eastern
# 24                     Flemingdon Park,Don Mills South
# 25                                Church and Wellesley
# 26                                         The Beaches
# 27                             Silver Hills,York Mills
# 28             Chinatown,Grange Park,Kensington Market
# 29                                             Leaside
# ..                                                 ...
# 73                      Woodbine Gardens,Parkview Hill
# 74   Albion Gardens,Beaumond Heights,Humbergate,Jam...
# 75                                    Islington Avenue
# 76           East Birchmount Park,Ionview,Kennedy Park
# 77                                           Parkwoods
# 78                               Parkdale,Roncesvalles
# 79                               Alderwood,Long Branch
# 80         Del Ray,Keelesdale,Mount Dennis,Silverthorn
# 81                                    Thorncliffe Park
# 82                                    Victoria Village
# 83                                              Woburn
# 84         The Kingsway,Montgomery Road,Old Mill North
# 85                   The Annex,North Midtown,Yorkville
# 86                                     Willowdale West
# 87   Humber Bay,King's Mill Park,Kingsway Park Sout...
# 88                Highland Creek,Rouge Hill,Port Union
# 89               Canada Post Gateway Processing Centre
# 90                        The Junction North,Runnymede
# 91                                            Rosedale
# 92                                  Humewood-Cedarvale
# 93                             Ryerson,Garden District
# 94                       The Beaches West,India Bazaar
# 95                                       Lawrence Park
# 96                                           Westmount
# 97                    Downsview,North Park,Upwood Park
# 98                                    Davisville North
# 99                                     L'Amoreaux West
# 100                                       Harbourfront
# 101      Cliffcrest,Cliffside,Scarborough Village West
# 102                   Bedford Park,Lawrence Manor East
#
# [103 rows x 3 columns]

# %% [markdown]
# ## Size of DF

# %%
postal_code_df.shape
# Out:
# (103, 3)
